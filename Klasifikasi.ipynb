# %%
import pandas as pd

# %% [markdown]
# ## Preparasi Data

# %%
data_clean_all = pd.read_csv("Data part 1 Clean.csv")
data_clean_all.head()
# Out:
#    review_id         reviewer                          movie  rating  \
# 0  rw5704482    raeldor-96879            After Life (2019– )     9.0
# 1  rw5704483          dosleeb  The Valhalla Murders (2019– )     6.0
# 2  rw5704484  brightconscious           Special OPS (2020– )     7.0
# 3  rw5704485       gasconyway              #BlackAF (2020– )     8.0
# 4  rw5704487     mmason-15867             The Droving (2020)     2.0
#
#           review_summary review_date  spoiler_tag  \
# 0   Very Strong Season 2  3 May 2020            0
# 1  Icelandic detectives?  3 May 2020            0
# 2        Nothing special  3 May 2020            0
# 3               Good but  3 May 2020            0
# 4       An honest review  3 May 2020            0
#
#                                        review_detail       helpful
# 0  I enjoyed the first season, but I must say I t...    ['1', '1']
# 1  I know Iceland is a small country and police d...    ['2', '2']
# 2  Except K K , no other actor looks comfortable ...    ['0', '0']
# 3  I'm guessing that as a 62 year old white woman...    ['5', '9']
# 4  Here's the truth. There's not much to this mov...  ['26', '41']

# %%
data_berlabel = pd.read_csv("data_sampling_labelbagging.csv")
data_berlabel.head()
# Out:
#    review_id                          movie  rating  \
# 0  rw5704482            After Life (2019– )     9.0
# 1  rw5704483  The Valhalla Murders (2019– )     6.0
# 2  rw5704484           Special OPS (2020– )     7.0
# 3  rw5704485              #BlackAF (2020– )     8.0
# 4  rw5704487             The Droving (2020)     2.0
#
#                                        review_detail  label_komen
# 0  I enjoyed the first season, but I must say I t...            1
# 1  I know Iceland is a small country and police d...            0
# 2  Except K K , no other actor looks comfortable ...            0
# 3  I'm guessing that as a 62 year old white woman...            1
# 4  Here's the truth. There's not much to this mov...            0

# %%
dict_berlabel = {}
for i in range(data_berlabel.shape[0]) :
    dict_berlabel[data_berlabel["review_id"][i]] = data_berlabel["label_komen"][i]

for i in dict_berlabel :
    print(i,dict_berlabel[i])
    break
# Out:
# rw5704482 1

# %%
dict_klasifikasi = {"review_id" : [], "review_detail" : []}

for i in range(data_clean_all.shape[0]) :
    if data_clean_all["review_id"][i] not in dict_berlabel :
        dict_klasifikasi["review_id"].append(data_clean_all["review_id"][i])
        dict_klasifikasi["review_detail"].append(data_clean_all["review_detail"][i])
        
df_klasifikasi = pd.DataFrame(dict_klasifikasi)
df_klasifikasi.head()
# Out:
#    review_id                                      review_detail
# 0  rw5704548  I purchased the movie on Amazon so I have it d...
# 1  rw5704928  A very, very bad episode and out of content th...
# 2  rw5705227  Maybe this show should call Lex Luthor and no ...
# 3  rw5705231  It's very good and it's always good to see a f...
# 4  rw5705299  Unlike some others who have commented here, I ...

# %%
import pandas as pd
import re
import nltk
from IPython.display import display

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /home/deskafim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/deskafim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/deskafim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/deskafim/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def case_folding(text):
    if pd.isna(text):
        return ""
    text = str(text).lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df_klasifikasi['case_folded'] = df_klasifikasi['review_detail'].apply(case_folding)

display(df_klasifikasi[['review_detail', 'case_folded']].head(3))
# Out:
#                                        review_detail  \
# 0  I purchased the movie on Amazon so I have it d...
# 1  A very, very bad episode and out of content th...
# 2  Maybe this show should call Lex Luthor and no ...
#
#                                          case_folded
# 0  i purchased the movie on amazon so i have it d...
# 1  a very very bad episode and out of content the...
# 2  maybe this show should call lex luthor and no ...

# %%
from nltk.tokenize import word_tokenize

df_klasifikasi['tokenized'] = df_klasifikasi['case_folded'].apply(word_tokenize)

display(df_klasifikasi[['case_folded', 'tokenized']].head(3))
# Out:
#                                          case_folded  \
# 0  i purchased the movie on amazon so i have it d...
# 1  a very very bad episode and out of content the...
# 2  maybe this show should call lex luthor and no ...
#
#                                            tokenized
# 0  [i, purchased, the, movie, on, amazon, so, i, ...
# 1  [a, very, very, bad, episode, and, out, of, co...
# 2  [maybe, this, show, should, call, lex, luthor,...

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def remove_stopwords(tokens):
    return [word for word in tokens if word not in stop_words]

df_klasifikasi['no_stopwords'] = df_klasifikasi['tokenized'].apply(remove_stopwords)

display(df_klasifikasi[['tokenized', 'no_stopwords']].head(3))
# Out:
#                                            tokenized  \
# 0  [i, purchased, the, movie, on, amazon, so, i, ...
# 1  [a, very, very, bad, episode, and, out, of, co...
# 2  [maybe, this, show, should, call, lex, luthor,...
#
#                                         no_stopwords
# 0  [purchased, movie, amazon, digitally, buy, dvd...
# 1  [bad, episode, content, main, character, episode]
# 2        [maybe, show, call, lex, luthor, supergirl]

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

def lemmatize_text(tokens):
    return [lemmatizer.lemmatize(word) for word in tokens]

df_klasifikasi['lemmatized'] = df_klasifikasi['no_stopwords'].apply(lemmatize_text)

df_klasifikasi['clean_review'] = df_klasifikasi['lemmatized'].apply(lambda x: ' '.join(x))

display(df_klasifikasi[['no_stopwords', 'clean_review']].head(3))
# Out:
#                                         no_stopwords  \
# 0  [purchased, movie, amazon, digitally, buy, dvd...
# 1  [bad, episode, content, main, character, episode]
# 2        [maybe, show, call, lex, luthor, supergirl]
#
#                                         clean_review
# 0  purchased movie amazon digitally buy dvd watch...
# 1         bad episode content main character episode
# 2               maybe show call lex luthor supergirl

# %%
del df_klasifikasi["review_detail"]
del df_klasifikasi["case_folded"]
del df_klasifikasi["tokenized"]
del df_klasifikasi["no_stopwords"]
del df_klasifikasi["lemmatized"]

# %%
df_klasifikasi.head()
# Out:
#    review_id                                       clean_review
# 0  rw5704548  purchased movie amazon digitally buy dvd watch...
# 1  rw5704928         bad episode content main character episode
# 2  rw5705227               maybe show call lex luthor supergirl
# 3  rw5705231  good always good see familiar face comedy hard...
# 4  rw5705299  unlike others commented think kept political b...

# %% [markdown]
# ## Klasifikasi All Data Part 1 Clean

# %%
import pickle

def load_model(filepath):
    with open(filepath, 'rb') as file:
        return pickle.load(file)

tfidf = load_model('./BestModel2/Tf_Idf.pkl')
base_model_1 = load_model('./BestModel2/Naive_Bayes_B1.pkl')
base_model_2 = load_model('./BestModel2/Support_Vector_Machine_B2.pkl')
base_model_3 = load_model('./BestModel2/Random_Forest_B3.pkl')
meta_model = load_model('./BestModel2/Logistic_Linear_Meta.pkl')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 7
#       3 def load_model(filepath):
#       4     with open(filepath, 'rb') as file:
#       5         return pickle.load(file)
#       6
# ----> 7 tfidf = load_model('./BestModel2/Tf_Idf.pkl')
#       8 base_model_1 = load_model('./BestModel2/Naive_Bayes_B1.pkl')
#       9 base_model_2 = load_model('./BestModel2/Support_Vector_Machine_B2.pkl')
#      10 base_model_3 = load_model('./BestModel2/Random_Forest_B3.pkl')
#
# Cell In[17], line 5, in load_model(filepath)
#       3 def load_model(filepath):
#       4     with open(filepath, 'rb') as file:
# ----> 5         return pickle.load(file)
#
# File ~/miniconda3/envs/ml_gpu/lib/python3.11/site-packages/cudf/core/abc.py:188, in Serializable.host_deserialize(cls, header, frames)
#     166 """Perform device-side deserialization tasks.
#     167
#     168 Parameters
#    (...)    182 :meta private:
#     183 """
#     184 frames = [
#     185     cudf.core.buffer.as_buffer(f) if c else f
#     186     for c, f in zip(header["is-cuda"], map(memoryview, frames))
#     187 ]
# --> 188 obj = cls.device_deserialize(header, frames)
#     189 return obj
#
# File ~/miniconda3/envs/ml_gpu/lib/python3.11/site-packages/cudf/core/abc.py:142, in Serializable.device_deserialize(cls, header, frames)
#     137 typ = cls._name_type_map[header["type-serialized-name"]]
#     138 frames = [
#     139     cudf.core.buffer.as_buffer(f) if c else memoryview(f)
#     140     for c, f in zip(header["is-cuda"], frames, strict=True)
#     141 ]
# --> 142 return typ.deserialize(header, frames)
#
# File ~/miniconda3/envs/ml_gpu/lib/python3.11/site-packages/cudf/utils/performance_tracking.py:51, in _performance_tracking.<locals>.wrapper(*args, **kwargs)
#      43 if nvtx.enabled():
#      44     stack.enter_context(
#      45         nvtx.annotate(
#      46             message=func.__qualname__,
#    (...)     49         )
#      50     )
# ---> 51 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/ml_gpu/lib/python3.11/site-packages/cudf/core/series.py:913, in Series.deserialize(cls, header, frames)
#     909 @classmethod
#     910 @_performance_tracking
#     911 def deserialize(cls, header, frames):
#     912     index_nframes = header["index_frame_count"]
# --> 913     obj = super().deserialize(
#     914         header, frames[header["index_frame_count"] :]
#     915     )
#     917     index = cls.device_deserialize(header["index"], frames[:index_nframes])
#     918     obj.index = index
#
# File ~/miniconda3/envs/ml_gpu/lib/python3.11/site-packages/cudf/utils/performance_tracking.py:51, in _performance_tracking.<locals>.wrapper(*args, **kwargs)
#      43 if nvtx.enabled():
#      44     stack.enter_context(
#      45         nvtx.annotate(
#      46             message=func.__qualname__,
#    (...)     49         )
#      50     )
# ---> 51 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/ml_gpu/lib/python3.11/site-packages/cudf/core/frame.py:152, in Frame.deserialize(cls, header, frames)
#     147 else:
#     148     kwargs["label_dtype"] = (
#     149         np.dtype(dtype_header) if dtype_header is not None else None
#     150     )
# --> 152 columns = deserialize_columns(header["columns"], frames)
#     153 for metadata in [
#     154     "rangeindex",
#     155     "multiindex",
#     156     "level_names",
#     157 ]:
#     158     key = f"column_{metadata}"
#
# File ~/miniconda3/envs/ml_gpu/lib/python3.11/site-packages/cudf/core/column/column.py:2239, in deserialize_columns(headers, frames)
#    2237 col_frame_count = meta["frame_count"]
#    2238 col_typ = Serializable._name_type_map[meta["type-serialized-name"]]
# -> 2239 colobj = col_typ.deserialize(meta, frames[:col_frame_count])
#    2240 columns.append(colobj)
#    2241 # Advance frames
#
# File ~/miniconda3/envs/ml_gpu/lib/python3.11/site-packages/cudf/core/column/column.py:1282, in ColumnBase.deserialize(cls, header, frames)
#    1280         child, frames = unpack(h, frames)
#    1281         children.append(child)
# -> 1282 assert len(frames) == 0, "Deserialization did not consume all frames"
#    1283 return build_column(
#    1284     data=data,
#    1285     dtype=dtype,
#    (...)   1288     children=tuple(children),
#    1289 )
#
# AssertionError: Deserialization did not consume all frames

# %%
import cudf
import cupy as cp


data_gpu = cudf.Series(df_klasifikasi["clean_review"])

X_tfidf = tfidf.transform(data_gpu)
p1 = base_model_1.predict(X_tfidf)
p2 = base_model_2.predict(X_tfidf)
p3 = base_model_3.predict(X_tfidf)

X_meta = cudf.DataFrame({'p1': p1, 'p2': p2, 'p3': p3})

pred_gpu = meta_model.predict(X_meta)

if hasattr(pred_gpu, 'to_numpy'):
    pred_cpu = pred_gpu.to_numpy()
elif hasattr(pred_gpu, 'get'):
    pred_cpu = pred_gpu.get()
else:
    pred_cpu = pred_gpu
    
df_klasifikasi["label_komen"] = list(pred_cpu)

df_klasifikasi.head()
